# %% [markdown]
# ## Collecting Data
# Source of datasets :
#
# 1.   From IEEE : https://ieee-dataport.org/open-access/fruitsgb-top-indian-fruits-quality
# 2.   From Kaggle : https://www.kaggle.com/sriramr/fruits-fresh-and-rotten-for-classification
#
# But, we already combine both and make a drive. Below is the link for zip dataset (google drive):
# https://drive.google.com/file/d/1s0mHiO3wF_shUHO8NwjytBD1svWAFSr_/view?usp=sharing

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.5.0

# %%
from google.colab import drive

#to connect drive account to colab
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import shutil
import os

source = r'/content/gdrive/MyDrive/dataset.zip'
destination = r'/content/dataset.zip'

# %%
shutil.copyfile(source, destination)
# Out:
# '/content/dataset.zip'

# %%
#extract zip file
import zipfile 
local_zip = destination
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/content/')
zip_ref.close()

# %% [markdown]
# ## Explore Dataset and Preprocess

# %%
path = r'/content/dataset/'
categories = os.listdir(path)
categories
# Out:
# ['Apple_Bad',
#  'Apple_Good',
#  'Banana_Good',
#  'Orange_Bad',
#  'Orange_Good',
#  'Banana_Bad']

# %%
def count_num_file(path,name_dir):
  num_file = len(os.listdir(path+name_dir))
  return num_file
  
for categorie in categories :
  print("{} folder : {} file ".format(categorie, count_num_file(path,categorie)))
# Out:
# Apple_Bad folder : 3954 file
# Apple_Good folder : 3088 file
# Banana_Good folder : 2963 file
# Orange_Bad folder : 3009 file
# Orange_Good folder : 2869 file
# Banana_Bad folder : 3756 file

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
# %matplotlib inline


def plot_img(name):
  img = [fn for fn in os.listdir(f'{path}/{name}')]
  
  select_img= np.random.choice(img, 3, replace = False)

  fig = plt.figure(figsize = (8,6))
  for i in range(3):
      if i < 3:
        fp = f'{path}/{name}/{select_img[i]}'
        label = {name}
      
      ax = fig.add_subplot(1,3,i+1)
      
      fn = image.load_img(fp, target_size = (100,100))
      plt.imshow(fn)
      plt.title(label)
      plt.axis('off')
  plt.show()

for categorie in categories:
  plot_img(categorie)

# %%
def count_ext(path,categorie):
  count_img = 0
  
  for i in os.listdir(path+categorie):
    ext = os.path.splitext(os.path.basename(f'{path}{categorie}/{i}'))[1]
    if ext == '.jpg':
      count_img +=1
    
  print("{} have {} image with jpg extension".format(categorie,count_img))

for categorie in categories:
  count_ext(path,categorie)
# Out:
# Apple_Bad have 1003 image with jpg extension
# Apple_Good have 1000 image with jpg extension
# Banana_Good have 1000 image with jpg extension
# Orange_Bad have 1010 image with jpg extension
# Orange_Good have 1006 image with jpg extension
# Banana_Bad have 1000 image with jpg extension

# %%
path_train = '/content/dataset_result/train/'
path_val = '/content/dataset_result/val/'

for categorie in categories:
  try:
    os.makedirs(path_train+categorie,exist_ok=True)
    print("Directory {} created successfully".format(path_train+categorie))
  except OSError as error:
    print("Directory {} can not be created".format(path_train+categorie))

for categorie in categories:
  try:
    os.makedirs(path_val+categorie,exist_ok=True)
    print("Directory {} created successfully".format(path_val+categorie))
  except OSError as error:
    print("Directory {} can not be created".format(path_val+categorie))
# Out:
# Directory /content/dataset_result/train/Apple_Bad created successfully
# Directory /content/dataset_result/train/Apple_Good created successfully
# Directory /content/dataset_result/train/Banana_Good created successfully
# Directory /content/dataset_result/train/Orange_Bad created successfully
# Directory /content/dataset_result/train/Orange_Good created successfully
# Directory /content/dataset_result/train/Banana_Bad created successfully
# Directory /content/dataset_result/val/Apple_Bad created successfully
# Directory /content/dataset_result/val/Apple_Good created successfully
# Directory /content/dataset_result/val/Banana_Good created successfully
# Directory /content/dataset_result/val/Orange_Bad created successfully
# Directory /content/dataset_result/val/Orange_Good created successfully
# Directory /content/dataset_result/val/Banana_Bad created successfully

# %% [markdown]
# Convert the jpg image to png. Splitting train and val dataset manually, because we want to make sure that data from kaggle (web scrapping) is on training.
#
#
# *   Moving all data from kaggle to training
# *   Divide and convert to png data from IEEE
#
# So, training : 80% (all kaggle data with some IEEE data) and validation : 20% (data from IEEE)

# %%
def split_file(path, name_dir):
  src_files= os.listdir(path+name_dir)
  #print(src_files)
  val_size = 0.2*count_num_file(path, name_dir)
  count_val_file = 0

  for file_name in src_files:
      split_ext = os.path.splitext(os.path.basename(f'{file_name}'))

      if split_ext[1] == '.png':
        src = os.path.join(path+name_dir, file_name)
        
        dest = os.path.join(path_train+name_dir, file_name)
     
        shutil.copy(src, dest)

      elif split_ext[1] == '.jpg':
        if count_val_file > val_size :
          src = os.path.join(path+name_dir, file_name)
     
          dest = os.path.join(path_train+name_dir, split_ext[0]+'.png')

          shutil.copy(src, dest)
          #print('succes copy from {} to {}'.format(src,dest))
        else :
          src = os.path.join(path+name_dir, file_name)
          dest = os.path.join(path_val+name_dir, split_ext[0]+'.png')
          shutil.copy(src,dest)
          count_val_file = count_val_file + 1
         # print('succes copy from {} to {}'.format(src,dest))

# %%
for categorie in categories:
  split_file(path, categorie)

# %%
#count number of file in val directory
for categorie in categories:
  print("{} validation folder have : {} files".format(categorie,count_num_file(path_val,categorie)))
# Out:
# Apple_Bad validation folder have : 791 files
# Apple_Good validation folder have : 618 files
# Banana_Good validation folder have : 593 files
# Orange_Bad validation folder have : 602 files
# Orange_Good validation folder have : 574 files
# Banana_Bad validation folder have : 752 files

# %%
#count number of file in train directory
for categorie in categories:
  print("{} training folder have : {} files".format(categorie,count_num_file(path_train,categorie)))
# Out:
# Apple_Bad training folder have : 3162 files
# Apple_Good training folder have : 2470 files
# Banana_Good training folder have : 2369 files
# Orange_Bad training folder have : 2406 files
# Orange_Good training folder have : 2294 files
# Banana_Bad training folder have : 3004 files

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#Add generator and do augmentation to dataset
train_datagen = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=20,
                    zoom_range=0.2,
                    width_shift_range=0.2,
                    height_shift_range=0.2,
                    horizontal_flip=True,
                    vertical_flip=True,
                    fill_mode = 'nearest')
val_datagen = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=20,
                    zoom_range=0.2,
                    width_shift_range=0.2,
                    height_shift_range=0.2,
                    horizontal_flip=True,
                    vertical_flip=True,
                    fill_mode = 'nearest')

# %%
train_generator = train_datagen.flow_from_directory(
        path_train,  
        target_size=(100, 100),
        batch_size=32,
        shuffle=True, 
        class_mode='categorical')
val_generator = train_datagen.flow_from_directory(
        path_val,  
        target_size=(100, 100),
        batch_size=32,
        shuffle=True, 
        class_mode='categorical')
# Out:
# Found 15705 images belonging to 6 classes.
# Found 3930 images belonging to 6 classes.

# %% [markdown]
# **Make model using CNN**

# %%
model = tf.keras.models.Sequential([
    
    tf.keras.layers.Conv2D(128, (3,3), activation='relu', input_shape=(100, 100, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.5),
    
    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(0.5),
   
    tf.keras.layers.Dense(6, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 98, 98, 128)       3584
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 49, 49, 128)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 47, 47, 128)       147584
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 23, 23, 128)       0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 23, 23, 128)       0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 67712)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               34669056
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 6)                 3078
# =================================================================
# Total params: 34,823,302
# Trainable params: 34,823,302
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

# %%
history=model.fit(
      train_generator,
      steps_per_epoch=25, 
      epochs=50,
      validation_data=val_generator, 
      validation_steps=5, 
      verbose=1)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 6s 236ms/step - loss: 2.0136 - accuracy: 0.3100 - val_loss: 1.6731 - val_accuracy: 0.3812
# Epoch 2/50
# 25/25 [==============================] - 6s 229ms/step - loss: 1.4445 - accuracy: 0.4187 - val_loss: 1.5254 - val_accuracy: 0.4000
# Epoch 3/50
# 25/25 [==============================] - 6s 227ms/step - loss: 1.3477 - accuracy: 0.4725 - val_loss: 1.6068 - val_accuracy: 0.3812
# Epoch 4/50
# 25/25 [==============================] - 6s 227ms/step - loss: 1.2464 - accuracy: 0.5038 - val_loss: 1.4237 - val_accuracy: 0.3438
# Epoch 5/50
# 25/25 [==============================] - 6s 226ms/step - loss: 1.1490 - accuracy: 0.5462 - val_loss: 1.5330 - val_accuracy: 0.3750
# Epoch 6/50
# 25/25 [==============================] - 6s 227ms/step - loss: 1.1348 - accuracy: 0.5537 - val_loss: 1.3603 - val_accuracy: 0.5000
# Epoch 7/50
# 25/25 [==============================] - 6s 226ms/step - loss: 1.0155 - accuracy: 0.6212 - val_loss: 1.3637 - val_accuracy: 0.4062
# Epoch 8/50
# 25/25 [==============================] - 6s 231ms/step - loss: 0.9827 - accuracy: 0.6338 - val_loss: 1.4089 - val_accuracy: 0.4750
# Epoch 9/50
# 25/25 [==============================] - 6s 230ms/step - loss: 0.9833 - accuracy: 0.6413 - val_loss: 1.4793 - val_accuracy: 0.4313
# Epoch 10/50
# 25/25 [==============================] - 6s 223ms/step - loss: 0.9633 - accuracy: 0.6413 - val_loss: 1.2969 - val_accuracy: 0.4688
# Epoch 11/50
# 25/25 [==============================] - 6s 230ms/step - loss: 1.0119 - accuracy: 0.6062 - val_loss: 1.1936 - val_accuracy: 0.5250
# Epoch 12/50
# 25/25 [==============================] - 6s 228ms/step - loss: 0.8839 - accuracy: 0.6587 - val_loss: 1.5138 - val_accuracy: 0.4125
# Epoch 13/50
# 25/25 [==============================] - 6s 225ms/step - loss: 0.9366 - accuracy: 0.6463 - val_loss: 1.1271 - val_accuracy: 0.5562
# Epoch 14/50
# 25/25 [==============================] - 6s 227ms/step - loss: 0.8956 - accuracy: 0.6463 - val_loss: 1.2768 - val_accuracy: 0.5063
# Epoch 15/50
# 25/25 [==============================] - 6s 223ms/step - loss: 0.8298 - accuracy: 0.6737 - val_loss: 1.2159 - val_accuracy: 0.5188
# Epoch 16/50
# 25/25 [==============================] - 6s 222ms/step - loss: 0.7972 - accuracy: 0.6988 - val_loss: 1.1500 - val_accuracy: 0.5562
# Epoch 17/50
# 25/25 [==============================] - 6s 225ms/step - loss: 0.7594 - accuracy: 0.7212 - val_loss: 1.3606 - val_accuracy: 0.3938
# Epoch 18/50
# 25/25 [==============================] - 6s 226ms/step - loss: 0.7417 - accuracy: 0.7400 - val_loss: 1.1732 - val_accuracy: 0.5813
# Epoch 19/50
# 25/25 [==============================] - 6s 225ms/step - loss: 0.7187 - accuracy: 0.7387 - val_loss: 0.9490 - val_accuracy: 0.6750
# Epoch 20/50
# 25/25 [==============================] - 6s 227ms/step - loss: 0.7366 - accuracy: 0.7250 - val_loss: 1.1217 - val_accuracy: 0.5813
# Epoch 21/50
# 25/25 [==============================] - 6s 224ms/step - loss: 0.7460 - accuracy: 0.7262 - val_loss: 1.1488 - val_accuracy: 0.5938
# Epoch 22/50
# 25/25 [==============================] - 6s 224ms/step - loss: 0.7269 - accuracy: 0.7462 - val_loss: 1.1994 - val_accuracy: 0.5250
# Epoch 23/50
# 25/25 [==============================] - 6s 224ms/step - loss: 0.7149 - accuracy: 0.7500 - val_loss: 1.1775 - val_accuracy: 0.4875
# Epoch 24/50
# 25/25 [==============================] - 6s 225ms/step - loss: 0.7733 - accuracy: 0.7000 - val_loss: 1.0949 - val_accuracy: 0.5562
# Epoch 25/50
# 25/25 [==============================] - 6s 227ms/step - loss: 0.6899 - accuracy: 0.7425 - val_loss: 1.1594 - val_accuracy: 0.5250
# Epoch 26/50
# 25/25 [==============================] - 6s 226ms/step - loss: 0.6997 - accuracy: 0.7375 - val_loss: 0.9583 - val_accuracy: 0.6062
# Epoch 27/50
# 25/25 [==============================] - 6s 226ms/step - loss: 0.6918 - accuracy: 0.7337 - val_loss: 1.0585 - val_accuracy: 0.6500
# Epoch 28/50
# 25/25 [==============================] - 6s 223ms/step - loss: 0.7015 - accuracy: 0.7475 - val_loss: 1.1441 - val_accuracy: 0.5813
# Epoch 29/50
# 25/25 [==============================] - 6s 225ms/step - loss: 0.7170 - accuracy: 0.7312 - val_loss: 0.8907 - val_accuracy: 0.6562
# Epoch 30/50
# 25/25 [==============================] - 6s 224ms/step - loss: 0.6040 - accuracy: 0.7613 - val_loss: 1.0572 - val_accuracy: 0.5562
# Epoch 31/50
# 25/25 [==============================] - 6s 224ms/step - loss: 0.6344 - accuracy: 0.7700 - val_loss: 0.9074 - val_accuracy: 0.6375
# Epoch 32/50
# 25/25 [==============================] - 6s 227ms/step - loss: 0.6401 - accuracy: 0.7600 - val_loss: 1.1212 - val_accuracy: 0.5625
# Epoch 33/50
# 25/25 [==============================] - 6s 220ms/step - loss: 0.6936 - accuracy: 0.7375 - val_loss: 1.0366 - val_accuracy: 0.6313
# Epoch 34/50
# 25/25 [==============================] - 6s 227ms/step - loss: 0.6087 - accuracy: 0.7887 - val_loss: 1.0191 - val_accuracy: 0.5875
# Epoch 35/50
# 25/25 [==============================] - 6s 224ms/step - loss: 0.7032 - accuracy: 0.7550 - val_loss: 1.0743 - val_accuracy: 0.5562
# Epoch 36/50
# 25/25 [==============================] - 5s 220ms/step - loss: 0.6810 - accuracy: 0.7550 - val_loss: 0.9484 - val_accuracy: 0.6000
# Epoch 37/50
# 25/25 [==============================] - 6s 226ms/step - loss: 0.5974 - accuracy: 0.7638 - val_loss: 0.8134 - val_accuracy: 0.7125
# Epoch 38/50
# 25/25 [==============================] - 6s 223ms/step - loss: 0.6957 - accuracy: 0.7350 - val_loss: 1.0118 - val_accuracy: 0.6062
# Epoch 39/50
# 25/25 [==============================] - 6s 228ms/step - loss: 0.5737 - accuracy: 0.7750 - val_loss: 1.0445 - val_accuracy: 0.6625
# Epoch 40/50
# 25/25 [==============================] - 6s 226ms/step - loss: 0.5649 - accuracy: 0.7862 - val_loss: 0.8263 - val_accuracy: 0.6313
# Epoch 41/50
# 25/25 [==============================] - 6s 225ms/step - loss: 0.6274 - accuracy: 0.7525 - val_loss: 0.8199 - val_accuracy: 0.7000
# Epoch 42/50
# 25/25 [==============================] - 6s 229ms/step - loss: 0.5473 - accuracy: 0.8075 - val_loss: 0.8363 - val_accuracy: 0.6687
# Epoch 43/50
# 25/25 [==============================] - 6s 226ms/step - loss: 0.6161 - accuracy: 0.7638 - val_loss: 0.8543 - val_accuracy: 0.6625
# Epoch 44/50
# 25/25 [==============================] - 6s 225ms/step - loss: 0.5613 - accuracy: 0.8000 - val_loss: 0.7059 - val_accuracy: 0.7937
# Epoch 45/50
# 25/25 [==============================] - 6s 224ms/step - loss: 0.5117 - accuracy: 0.7987 - val_loss: 0.8681 - val_accuracy: 0.6687
# Epoch 46/50
# 25/25 [==============================] - 6s 223ms/step - loss: 0.6173 - accuracy: 0.7750 - val_loss: 0.8978 - val_accuracy: 0.6375
# Epoch 47/50
# 25/25 [==============================] - 6s 232ms/step - loss: 0.5213 - accuracy: 0.8025 - val_loss: 0.6430 - val_accuracy: 0.7875
# Epoch 48/50
# 25/25 [==============================] - 6s 227ms/step - loss: 0.4987 - accuracy: 0.8062 - val_loss: 0.9150 - val_accuracy: 0.6938
# Epoch 49/50
# 25/25 [==============================] - 6s 228ms/step - loss: 0.5019 - accuracy: 0.8112 - val_loss: 0.8259 - val_accuracy: 0.6562
# Epoch 50/50
# 25/25 [==============================] - 6s 227ms/step - loss: 0.5129 - accuracy: 0.8300 - val_loss: 0.7765 - val_accuracy: 0.6687

# %%
import keras
from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
